# %% [markdown]
# <a href="https://colab.research.google.com/github/TaniaR078/Final_Project_MSIB/blob/main/Analisi_awal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression

import statsmodels.api as sa
import statsmodels.formula.api as sm
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Sebelum memulai pengerjaan Analisis Data, disini kita tampilkan dulu untuk data responden dan juga data Total Murid

# %%
data = pd.read_excel('/content/Final Project 6C.xlsx')
data2 = pd.read_excel('/content/Total Murid.xlsx')

# %%
data.head()
# Out:
#                 Tanggal Input                  Nama Murid Jenjang  \
# 0  2022-09-15 12:49:45.178000  Mah***********************      KB
# 1  2022-09-15 13:59:36.972000             Pri************      KB
# 2  2022-09-15 19:10:54.693000         Alu****************  PAUD B
# 3  2022-09-15 19:25:51.080000       Azk******************  PAUD A
# 4  2022-09-15 19:33:49.685000                  Ray*******  PAUD A
#
#        Nama Ayah/Ibu     Lokasi Belajar  Dekat/Tidak Jarak Sekolah  \
# 0        Cut********  Lokasi Belajar 15                          3
# 1     Moh***********  Lokasi Belajar 22                          4
# 2  Pan**************   Lokasi Belajar 3                          4
# 3    Nur************  Lokasi Belajar 21                          3
# 4               Ran*  Lokasi Belajar 20                          2
#
#    Kemudahan Mencari Lokasi  Kondisi Lingkungan Belajar  \
# 0                         3                           2
# ...

# %% [markdown]
# SOAL NOMOR 1
#
# Bagaimana komposisi responden yang mengisi kuesioner?

# %%
data_responden_jenjang = data.groupby('Jenjang')['Nama Murid'].count().reset_index(name='Jumlah Responden')

# %%
data_responden_lokasibelajar = data.groupby('Lokasi Belajar')['Nama Murid'].count().reset_index(name='Jumlah Responden')

# %%
data_responden_jenjang
# Out:
#    Jenjang  Jumlah Responden
# 0       KB                70
# 1   PAUD A                61
# 2   PAUD B                60
# 3     SD 1                36
# 4     SD 2                21
# 5     SD 3                 3
# 6     SD 4                 7
# 7     SD 5                 7
# 8     SD 6                 1
# 9   SMA 10                 5
# 10  SMA 11                 3
# 11   SMP 7                 9
# 12   SMP 8                 2

# %%
data_responden_lokasibelajar
# Out:
#        Lokasi Belajar  Jumlah Responden
# 0    Lokasi Belajar 1                 8
# 1   Lokasi Belajar 10                 1
# 2   Lokasi Belajar 11                 2
# 3   Lokasi Belajar 12                 5
# 4   Lokasi Belajar 13                10
# 5   Lokasi Belajar 14                 3
# 6   Lokasi Belajar 15                50
# 7   Lokasi Belajar 16                40
# 8   Lokasi Belajar 17                10
# 9   Lokasi Belajar 18                 3
# 10  Lokasi Belajar 19                 7
# 11   Lokasi Belajar 2                24
# 12  Lokasi Belajar 20                13
# 13  Lokasi Belajar 21                52
# 14  Lokasi Belajar 22                12
# 15  Lokasi Belajar 23                 9
# 16   Lokasi Belajar 3                 8
# 17   Lokasi Belajar 4                 9
# 18   Lokasi Belajar 5                 2
# 19   Lokasi Belajar 7                 3
# 20   Lokasi Belajar 8                 8
# 21   Lokasi Belajar 9                 6

# %% [markdown]
# SOAL NOMOR 2
#
# Lokasi Belajar manakah dengan jumlah responden terbanyak?
#
# Lalu, jika kita mengikutsertakan data total murid di tiap lokasi belajar, maka lokasi belajar manakah dengan tingkat partisipasi mengisi kuisioner paling banyak?

# %%
#Nomor 2
adata['Lokasi Belajar'].value_counts()
# Out:
# Lokasi Belajar 21    52
# Lokasi Belajar 15    50
# Lokasi Belajar 16    40
# Lokasi Belajar 2     24
# Lokasi Belajar 20    13
# Lokasi Belajar 22    12
# Lokasi Belajar 17    10
# Lokasi Belajar 13    10
# Lokasi Belajar 23     9
# Lokasi Belajar 4      9
# Lokasi Belajar 3      8
# Lokasi Belajar 8      8
# Lokasi Belajar 1      8
# Lokasi Belajar 19     7
# Lokasi Belajar 9      6
# Lokasi Belajar 12     5
# Lokasi Belajar 7      3
# Lokasi Belajar 14     3
# Lokasi Belajar 18     3
# Lokasi Belajar 11     2
# Lokasi Belajar 5      2
# Lokasi Belajar 10     1
# Name: Lokasi Belajar, dtype: int64

# %% [markdown]
# Jika dilihat pada hasil perhitungan di atas,Lokasi Belajar yang memiliki jumlah responden terbanyak adalah **Lokasi Belajar 21**

# %%
data_No2 = data.groupby('Lokasi Belajar')['Nama Murid'].count().reset_index(name='Jumlah Responden')

# %%
data_No2
# Out:
#        Lokasi Belajar  Jumlah Responden
# 0    Lokasi Belajar 1                 8
# 1   Lokasi Belajar 10                 1
# 2   Lokasi Belajar 11                 2
# 3   Lokasi Belajar 12                 5
# 4   Lokasi Belajar 13                10
# 5   Lokasi Belajar 14                 3
# 6   Lokasi Belajar 15                50
# 7   Lokasi Belajar 16                40
# 8   Lokasi Belajar 17                10
# 9   Lokasi Belajar 18                 3
# 10  Lokasi Belajar 19                 7
# 11   Lokasi Belajar 2                24
# 12  Lokasi Belajar 20                13
# 13  Lokasi Belajar 21                52
# 14  Lokasi Belajar 22                12
# 15  Lokasi Belajar 23                 9
# 16   Lokasi Belajar 3                 8
# 17   Lokasi Belajar 4                 9
# 18   Lokasi Belajar 5                 2
# 19   Lokasi Belajar 7                 3
# 20   Lokasi Belajar 8                 8
# 21   Lokasi Belajar 9                 6

# %%
data2
# Out:
#        Lokasi Belajar  Total Murid
# 0    Lokasi Belajar 1           15
# 1    Lokasi Belajar 2           28
# 2    Lokasi Belajar 3           13
# 3    Lokasi Belajar 4           10
# 4    Lokasi Belajar 5            8
# 5    Lokasi Belajar 7            9
# 6    Lokasi Belajar 8            8
# 7    Lokasi Belajar 9           12
# 8   Lokasi Belajar 10           10
# 9   Lokasi Belajar 11            7
# 10  Lokasi Belajar 12           20
# 11  Lokasi Belajar 13           11
# 12  Lokasi Belajar 14           11
# 13  Lokasi Belajar 15           80
# 14  Lokasi Belajar 16           50
# 15  Lokasi Belajar 17           30
# 16  Lokasi Belajar 18           13
# 17  Lokasi Belajar 19            8
# 18  Lokasi Belajar 20           30
# 19  Lokasi Belajar 21           60
# 20  Lokasi Belajar 22           18
# 21  Lokasi Belajar 23           17

# %%
datafinal = data_No2.merge(data2, how='left', left_on='Lokasi Belajar', right_on=' Lokasi Belajar')
display(datafinal)
# Out:
#        Lokasi Belajar  Jumlah Responden     Lokasi Belajar  Total Murid
# 0    Lokasi Belajar 1                 8   Lokasi Belajar 1           15
# 1   Lokasi Belajar 10                 1  Lokasi Belajar 10           10
# 2   Lokasi Belajar 11                 2  Lokasi Belajar 11            7
# 3   Lokasi Belajar 12                 5  Lokasi Belajar 12           20
# 4   Lokasi Belajar 13                10  Lokasi Belajar 13           11
# 5   Lokasi Belajar 14                 3  Lokasi Belajar 14           11
# 6   Lokasi Belajar 15                50  Lokasi Belajar 15           80
# 7   Lokasi Belajar 16                40  Lokasi Belajar 16           50
# 8   Lokasi Belajar 17                10  Lokasi Belajar 17           30
# 9   Lokasi Belajar 18                 3  Lokasi Belajar 18           13
# 10  Lokasi Belajar 19                 7  Lokasi Belajar 19            8
# 11   Lokasi Belajar 2                24   Lokasi Belajar 2           28
# ...

# %%
print(data_No2.columns)
# Out:
# Index(['Lokasi Belajar', 'Jumlah Responden'], dtype='object')

# %%
print(data2.columns)
# Out:
# Index([' Lokasi Belajar', 'Total Murid'], dtype='object')

# %%
datafinal['Persentase Partisipasi'] = datafinal['Jumlah Responden'] / datafinal['Total Murid']*100

# %%
datafinal.sort_values(by=['Persentase Partisipasi'], ascending=[False], inplace=True)

# %%
datafinal = datafinal.drop([' Lokasi Belajar'], axis=1)

# %%
display(datafinal)
# Out:
#        Lokasi Belajar  Jumlah Responden  Total Murid  Persentase Partisipasi
# 20   Lokasi Belajar 8                 8            8              100.000000
# 4   Lokasi Belajar 13                10           11               90.909091
# 17   Lokasi Belajar 4                 9           10               90.000000
# 10  Lokasi Belajar 19                 7            8               87.500000
# 13  Lokasi Belajar 21                52           60               86.666667
# 11   Lokasi Belajar 2                24           28               85.714286
# 7   Lokasi Belajar 16                40           50               80.000000
# 14  Lokasi Belajar 22                12           18               66.666667
# 6   Lokasi Belajar 15                50           80               62.500000
# 16   Lokasi Belajar 3                 8           13               61.538462
# 0    Lokasi Belajar 1                 8           15               53.333333
# ...

# %% [markdown]
# Berdasarkan hasil perhitungan diatas, dengan membandingkan jumlah responden dan jumlah total murid di tiap lokasi belajar, dapat disimpulkan Lokasi Belajar dengan tingkat parsitipasi paling tinggi adalah **Lokasi Belajar 8, dengan persentase 100%**
